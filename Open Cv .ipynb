# %% [markdown]
# <a href="https://colab.research.google.com/github/Izelaceso/AI-Bootcamp-NIELIT/blob/main/Open%20Cv%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

image_path = '/content/download.jpeg'

# Load the image
img = cv2.imread(image_path)

# Check if the image was loaded successfully
if img is None:
    print(f"Error: Image not found at {image_path} or unable to load.")
else:
    cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=426x640>
